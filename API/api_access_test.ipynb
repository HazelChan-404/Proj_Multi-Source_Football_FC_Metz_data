# %% [markdown]
# # API Statsbomb

# %%
# !pip install statsbombpy
from statsbombpy import sb

creds = {
    "user": "xihui.chen@dauphine.eu",
    "passwd": "kBDNQGOm"
}
help(sb)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.2 MB/s eta 0:00:00
# ...
# Help on module statsbombpy.sb in statsbombpy:
#
# NAME
#     statsbombpy.sb
#
# FUNCTIONS
#     competition_events(country: str, division: str, season: str, gender: str = 'male', split: bool = False, filters: dict = {}, fmt: str = 'dataframe', creds: dict = {'user': None, 'passwd': None}, include_360_metrics=False) -> Union[pandas.core.frame.DataFrame, dict]
#
#     competition_frames(country: str, division: str, season: str, gender: str = 'male', fmt: str = 'dataframe', creds: dict = {'user': None, 'passwd': None}) -> Union[pandas.core.frame.DataFrame, dict]
#
#     competitions(fmt='dataframe', creds: dict = {'user': None, 'passwd': None})
#
# ...

# %%
sb.competitions(creds=creds)
# Out:
#    competition_id  season_id country_name competition_name competition_gender  \
# 0              75        316       Sweden      Allsvenskan               male
# 1              75        315       Sweden      Allsvenskan               male
# 2              88        316       Norway      Eliteserien               male
# 3              88        315       Norway      Eliteserien               male
# 4               7        318       France          Ligue 1               male
# 5               7        317       France          Ligue 1               male
# 6               8        318       France          Ligue 2               male
#
#    competition_youth  competition_international season_name  \
# 0              False                      False        2026
# 1              False                      False        2025
# 2              False                      False        2026
# 3              False                      False        2025
# ...

# %% [markdown]
# # API Skillcorner

# %%
# !pip install skillcorner
from skillcorner.client import SkillcornerClient

username = ''
secret_password = ''
client = SkillcornerClient(username="test1-fc-metz@skillcorner.com", password="M#TJbjMoYBPC7rkq")

help(client)
# Out:
# zsh:1: command not found: pip
# Help on SkillcornerClient in module skillcorner.client object:
#
# class SkillcornerClient(fitrequest.client.FitRequest)
#  |  SkillcornerClient(username=None, password=None, response_log_level=None, *args, **kwargs)
#  |
#  |  Method resolution order:
#  |      SkillcornerClient
#  |      fitrequest.client.FitRequest
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  get_competition_competition_editions(self, competition_id: str, params: dict = None, raise_for_status: bool = True, **kwargs)
#  |      Retrieve response from /api/competitions/{}/editions/ GET request. To learn more about it go to: https://skillcorner.com/api/docs/#/competitions/competitions_editions_list.
#  |
#  |  get_competition_editions(self, params: dict = None, raise_for_status: bool = True, **kwargs)
# ...

# %%
client.get_matches()
# Out:
# [{'id': 2054576,
#   'date_time': '2026-02-16T19:45:00Z',
#   'home_team': {'id': 94, 'short_name': 'SC Bastia'},
#   'away_team': {'id': 95, 'short_name': 'Troyes AC'},
#   'status': 'closed',
#   'competition_id': 12,
#   'season_id': 129,
#   'competition_edition_id': 1248},
#  {'id': 2054406,
#   'date_time': '2026-02-15T19:45:00Z',
#   'home_team': {'id': 73, 'short_name': 'Lyon'},
#   'away_team': {'id': 70, 'short_name': 'OGC Nice'},
#   'status': 'closed',
#   'competition_id': 3,
#   'season_id': 129,
#   'competition_edition_id': 1232},
#  {'id': 2054369,
#   'date_time': '2026-02-15T16:15:00Z',
#   'home_team': {'id': 72, 'short_name': 'FC Lorient'},
#   'away_team': {'id': 98, 'short_name': 'Angers SCO'},
#   'status': 'closed',
#   'competition_id': 3,
#   'season_id': 129,
#   'competition_edition_id': 1232},
#  {'id': 2054392,
#   'date_time': '2026-02-15T16:15:00Z',
#   'home_team': {'id': 97, 'short_name': 'FC Metz'},
# ...

# %%
client.get_competitions()
# Out:
# [{'id': 117,
#   'area': 'AFC',
#   'name': 'AFC Olympic Qualification Women Playoffs',
#   'gender': 'female',
#   'age_group': 'adult'},
#  {'id': 493,
#   'area': 'AFC',
#   'name': 'AFC U17 Asian Cup',
#   'gender': 'male',
#   'age_group': 'U17'},
#  {'id': 115,
#   'area': 'AFC',
#   'name': 'AFF Suzuki Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 445,
#   'area': 'AFC',
#   'name': 'ASEAN Club Championship',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 35,
#   'area': 'AFC',
#   'name': 'Asian Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 521,
#   'area': 'AFC',
#   'name': 'Asian Cup Qualification',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 602,
#   'area': 'AFC',
#   'name': 'CAFA Nations Cup',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 147,
#   'area': 'AFC',
#   'name': 'Champions League',
#   'gender': 'male',
#   'age_group': 'adult'},
#  {'id': 448,
#   'area': 'AFC',
# ...

# %%
client.get_teams()
# Out:
# [{'id': 2486,
#   'name': 'CR Flamengo U20',
#   'coach': None,
#   'stadium': {'id': 2166,
#    'name': 'Estádio da Gávea',
#    'city': 'Rio de Janeiro',
#    'capacity': None}},
#  {'id': 2495,
#   'name': 'Queen of the South FC',
#   'coach': None,
#   'stadium': {'id': 3369,
#    'name': 'Palmerston Park',
#    'city': 'Dumfries',
#    'capacity': 18690}},
#  {'id': 2489,
#   'name': 'Volta Redonda FC',
#   'coach': None,
#   'stadium': {'id': 2167,
#    'name': 'Estádio General Sylvio Raulino de Oliveira',
#    'city': 'Volta Redonda',
#    'capacity': None}},
#  {'id': 2690,
#   'name': 'FK Proleter Novi Sad',
#   'coach': None,
#   'stadium': {'id': 3646,
#    'name': 'Stadion Slana Bara',
#    'city': 'Novi Sad',
#    'capacity': 2000}},
#  {'id': 2503,
#   'name': 'Liebherr Grazer AK',
#   'coach': None,
#   'stadium': {'id': 2622, 'name': 'UPC-Arena', 'city': '', 'capacity': None}},
#  {'id': 2492,
#   'name': 'Criciuma EC',
#   'coach': None,
#   'stadium': {'id': 2169,
# ...

# %%
teams = client.get_teams(params={'matching': 'statsbomb'})
print(teams)
# Out:
# [{'id': 2486, 'name': 'CR Flamengo U20', 'coach': None, 'stadium': {'id': 2166, 'name': 'Estádio da Gávea', 'city': 'Rio de Janeiro', 'capacity': None}, 'statsbomb_id': None}, {'id': 2495, 'name': 'Queen of the South FC', 'coach': None, 'stadium': {'id': 3369, 'name': 'Palmerston Park', 'city': 'Dumfries', 'capacity': 18690}, 'statsbomb_id': None}, {'id': 2489, 'name': 'Volta Redonda FC', 'coach': None, 'stadium': {'id': 2167, 'name': 'Estádio General Sylvio Raulino de Oliveira', 'city': 'Volta Redonda', 'capacity': None}, 'statsbomb_id': None}, {'id': 2690, 'name': 'FK Proleter Novi Sad', 'coach': None, 'stadium': {'id': 3646, 'name': 'Stadion Slana Bara', 'city': 'Novi Sad', 'capacity': 2000}, 'statsbomb_id': '1275'}, {'id': 2503, 'name': 'Liebherr Grazer AK', 'coach': None, 'stadium': {'id': 2622, 'name': 'UPC-Arena', 'city': '', 'capacity': None}, 'statsbomb_id': '19672'}, {'id': 2492, 'name': 'Criciuma EC', 'coach': None, 'stadium': {'id': 2169, 'name': 'Estádio Heriberto Hülse'
# ...
